# %%
import time
# Start time
start = time.time()


# Read from volume
bronze_df = spark.read.format('csv')\
    .option('header',True)\
    .option('inferSchema',True)\
    .csv('/Volumes/project_catalog/medallion_project/myvolume/sales_data.csv')

# Save as bronze table
bronze_df.write.format('delta')\
    .mode('overwrite')\
    .saveAsTable('project_catalog.medallion_project.bronze_table')

# %%
spark.sql("OPTIMIZE project_catalog.medallion_project.bronze_table")
# Out:
# DataFrame[path: string, metrics: struct<numFilesAdded:bigint,numFilesRemoved:bigint,filesAdded:struct<min:bigint,max:bigint,avg:double,totalFiles:bigint,totalSize:bigint>,filesRemoved:struct<min:bigint,max:bigint,avg:double,totalFiles:bigint,totalSize:bigint>,partitionsOptimized:bigint,zOrderStats:struct<strategyName:string,inputCubeFiles:struct<num:bigint,size:bigint>,inputOtherFiles:struct<num:bigint,size:bigint>,inputNumCubes:bigint,mergedFiles:struct<num:bigint,size:bigint>,numOutputCubes:bigint,mergedNumCubes:bigint>,clusteringStats:struct<inputZCubeFiles:struct<numFiles:bigint,size:bigint>,inputOtherFiles:struct<numFiles:bigint,size:bigint>,inputNumZCubes:bigint,mergedFiles:struct<numFiles:bigint,size:bigint>,numOutputZCubes:bigint>,numBins:bigint,numBatches:bigint,totalConsideredFiles:bigint,totalFilesSkipped:bigint,preserveInsertionOrder:boolean,numFilesSkippedToReduceWriteAmplification:bigint,numBytesSkippedToReduceWriteAmplification:bigint,startTimeMs:bigint,endTimeMs:bigin
# ...

# %%
# Read again (for measurement)
bronze_df = spark.table('project_catalog.medallion_project.bronze_table')

# Metrics
row_count = bronze_df.count()

files = dbutils.fs.ls('/Volumes/project_catalog/medallion_project/myvolume/')
size_bytes = sum([f.size for f in files])

end = time.time()

print("=== Bronze Metrics ===")
print("Rows:", row_count)
print("Size (MB):", size_bytes / (1024*1024))
print("Execution Time (sec):", end - start)
# Out:
# === Bronze Metrics ===
# Rows: 1000
# Size (MB): 0.10021495819091797
# Execution Time (sec): 55.7605926990509
